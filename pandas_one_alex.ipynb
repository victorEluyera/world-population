# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\USER\Desktop\projects\pandatutorial Alex\world_population.csv',index_col='Country')
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia      41128771.00
# Albania             138  ALB            Tirana    Europe       2842321.00
# Algeria              34  DZA           Algiers    Africa      44903225.00
# American Samoa      213  ASM         Pago Pago   Oceania         44273.00
# Andorra             203  AND  Andorra la Vella    Europe         79824.00
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania         11572.00
# Western Sahara      172  ESH          El Aaiún    Africa        575986.00
# Yemen                46  YEM             Sanaa      Asia      33696614.00
# Zambia               63  ZMB            Lusaka    Africa      20017675.00
# Zimbabwe             74  ZWE            Harare    Africa      16320537.00
#
# ...

# %%
pd.set_option('display.float_format',lambda x:'%.2f' % x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Continent                    234 non-null    object
#  1   Country                      234 non-null    object
#  2   Rank                         234 non-null    int64
#  3   CCA3                         234 non-null    object
#  4   Capital                      234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
df.describe()
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           230.00           233.00           230.00
# mean  117.50      34632250.88      33600710.95      32066004.16
# std    67.69     137889172.44     135873196.61     131507146.34
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        406471.00        394295.00
# 50%   117.50       5762857.00       5456681.00       5244415.00
# 75%   175.75      22653719.00      21522626.00      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           227.00           227.00           229.00           229.00
# mean       30270164.48      26840495.26      19330463.93      16282884.78
# std       126074183.54     113352454.57      81309624.96      69345465.54
# min             596.00           651.00           700.00           733.00
# ...

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.36            -0.36
# 2022 Population             -0.36             1.00             1.00
# 2020 Population             -0.36             1.00             1.00
# 2015 Population             -0.35             1.00             1.00
# 2010 Population             -0.35             1.00             1.00
# 2000 Population             -0.34             0.99             1.00
# 1990 Population             -0.33             0.99             0.99
# 1980 Population             -0.33             0.99             0.99
# 1970 Population             -0.34             0.97             0.98
# Area (km²)                  -0.38             0.45             0.45
# Density (per km²)            0.13            -0.03            -0.03
# Growth Rate                 -0.22            -0.02            -0.03
# World Population Percentage -0.36             1.00             1.00
#
# ...

# %%
df.groupby('Continent').mean(numeric_only=True)
# Out:
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         92.16      25455879.68      23871435.26      21419703.57
# Asia           77.56      96327387.31      94955134.37      89165003.64
# Europe        124.50      15055371.82      14915843.92      15027454.12
# North America 160.93      15007403.40      14855914.82      14259596.25
# Oceania       188.52       2046386.32       1910148.96       1756664.48
# South America  97.57      31201186.29      30823574.50      29509599.71
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa             18898197.31      14598365.95      11376964.52
# Asia               89087770.00      80580835.11      48639995.33
# Europe             14712278.68      14817685.71      14785203.94
# North America      13568016.28      12151739.60      10531660.62
# Oceania             1613163.65       1357512.09       1162774.87
# ...

# %%
group_by_continent=df.groupby('Continent')

# %%
group_by_continent.count()
# Out:
#                Rank  CCA3  Capital  2022 Population  2020 Population  \
# Continent
# Africa           57    57       57               56               57
# Asia             50    50       50               49               49
# Europe           50    50       50               49               50
# North America    40    40       40               40               40
# Oceania          23    23       23               22               23
# South America    14    14       14               14               14
#
#                2015 Population  2010 Population  2000 Population  \
# Continent
# Africa                      54               54               56
# Asia                        50               47               46
# Europe                      49               50               49
# North America               40               40               40
# Oceania                     23               23               23
# South America               14               13               13
#
# ...

# %%
df.groupby('Continent').sum().sort_values('World Population Percentage', ascending=False)
# Out:
#                Rank                                               CCA3  \
# Continent
# Asia           3878  AFGARMAZEBHRBGDBTNBRNKHMCHNGEOHKGINDIDNIRNIRQI...
# Africa         5253  DZAAGOBENBWABFABDICMRCPVCAFTCDCOMDJICODEGYGNQE...
# Europe         6225  ALBANDAUTBLRBELBIHBGRHRVCYPCZEDNKESTFROFINFRAD...
# North America  6437  AIAATGABWBHSBRBBLZBMUVGBCANCYMCRICUBCUWDMADOMS...
# South America  1366         ARGBOLBRACHLCOLECUFLKGUFGUYPRYPERSURURYVEN
# Oceania        4336  ASMAUSCOKFJIPYFGUMKIRMHLFSMNRUNCLNZLNIUNFKPLWP...
#
#                                                          Capital  \
# Continent
# Asia           KabulYerevanBakuManamaDhakaThimphuBandar Seri ...
# Africa         AlgiersLuandaPorto-NovoGaboroneOuagadougouBuju...
# Europe         TiranaAndorra la VellaViennaMinskBrusselsSaraj...
# North America  The ValleySaint John’sOranjestadNassauBridgeto...
# South America  Buenos AiresSucreBrasiliaSantiagoBogotaQuitoSt...
# ...

# %%
df.groupby('Continent').agg({'World Population Percentage':['mean','max','count','sum','min']})
# Out:
#               World Population Percentage
#                                      mean    max count    sum   min
# Continent
# Africa                           0.313509   2.74    57  17.87  0.00
# Asia                             1.183800  17.88    50  59.19  0.01
# Europe                           0.186600   1.81    50   9.33  0.00
# North America                    0.187750   4.24    40   7.51  0.00
# Oceania                          0.023913   0.33    23   0.55  0.00
# South America                    0.391429   2.70    14   5.48  0.00

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     Continent            Country  Rank CCA3           Capital  \
# 0        Asia        Afghanistan    36  AFG             Kabul
# 1      Europe            Albania   138  ALB            Tirana
# 2      Africa            Algeria    34  DZA           Algiers
# 3     Oceania     American Samoa   213  ASM         Pago Pago
# 4      Europe            Andorra   203  AND  Andorra la Vella
# ..        ...                ...   ...  ...               ...
# 229   Oceania  Wallis and Futuna   226  WLF          Mata-Utu
# 230    Africa     Western Sahara   172  ESH          El Aaiún
# 231      Asia              Yemen    46  YEM             Sanaa
# 232    Africa             Zambia    63  ZMB            Lusaka
# 233    Africa           Zimbabwe    74  ZWE            Harare
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df[df['Continent']=='Oceania'].count()
# Out:
# Continent                      23
# Country                        23
# Rank                           23
# CCA3                           23
# Capital                        23
# 2022 Population                22
# 2020 Population                23
# 2015 Population                23
# 2010 Population                23
# 2000 Population                23
# 1990 Population                23
# 1980 Population                23
# 1970 Population                23
# Area (km²)                     23
# Density (per km²)              23
# Growth Rate                    23
# World Population Percentage    23
# dtype: int64

# %%
df.groupby(['Continent','Area (km²)']).agg({'World Population Percentage':['mean','max','count','sum','min']})
# Out:
#                          World Population Percentage
#                                                 mean   max count   sum   min
# Continent     Area (km²)
# Africa        374.0                             0.00  0.00     1  0.00  0.00
#               452.0                             0.00  0.00     1  0.00  0.00
#               964.0                             0.00  0.00     1  0.00  0.00
#               1862.0                            0.01  0.01     1  0.01  0.01
#               2040.0                            0.02  0.02     1  0.02  0.02
# ...                                              ...   ...   ...   ...   ...
# South America 1098581.0                         0.15  0.15     1  0.15  0.15
#               1141748.0                         0.65  0.65     1  0.65  0.65
#               1285216.0                         0.43  0.43     1  0.43  0.43
#               2780400.0                         0.57  0.57     1  0.57  0.57
# ...

# %%
df.groupby('Continent')['Area (km²)'].describe()
# Out:
#                count          mean           std      min        25%  \
# Continent
# Africa          56.0  5.378793e+05  6.010294e+05    374.0   34682.50
# Asia            50.0  6.427628e+05  1.495049e+06     30.0   31355.50
# Europe          50.0  4.602082e+05  2.406173e+06      1.0   10391.25
# North America   40.0  6.061044e+05  2.157052e+06     21.0     263.25
# Oceania         23.0  3.702209e+05  1.599770e+06     12.0     217.50
# South America   13.0  1.301303e+06  2.297169e+06  12173.0  181034.00
#
#                     50%         75%         max
# Continent
# Africa         297715.0   850153.25   2381741.0
# Asia           164302.5   506865.00   9706961.0
# Europe          53901.5   188697.50  17098242.0
# North America    1038.0    49278.25   9984670.0
# Oceania           702.0    15230.50   7692024.0
# South America  406752.0  1141748.00   8515767.0

# %%
df[df['Continent']=='North America']
# Out:
#          Continent                           Country  Rank CCA3  \
# 6    North America                          Anguilla   224  AIA
# 7    North America               Antigua and Barbuda   201  ATG
# 10   North America                             Aruba   198  ABW
# 14   North America                           Bahamas   176  BHS
# 17   North America                          Barbados   186  BRB
# 20   North America                            Belize   177  BLZ
# 22   North America                           Bermuda   206  BMU
# 28   North America            British Virgin Islands   221  VGB
# 35   North America                            Canada    39  CAN
# 37   North America                    Cayman Islands   205  CYM
# 45   North America                        Costa Rica   124  CRI
# 47   North America                              Cuba    85  CUB
# 48   North America                           Curacao   189  CUW
# 53   North America                          Dominica   204  DMA
# ...

# %%
df
# Out:
#     Continent            Country  Rank CCA3           Capital  \
# 0        Asia        Afghanistan    36  AFG             Kabul
# 1      Europe            Albania   138  ALB            Tirana
# 2      Africa            Algeria    34  DZA           Algiers
# 3     Oceania     American Samoa   213  ASM         Pago Pago
# 4      Europe            Andorra   203  AND  Andorra la Vella
# ..        ...                ...   ...  ...               ...
# 229   Oceania  Wallis and Futuna   226  WLF          Mata-Utu
# 230    Africa     Western Sahara   172  ESH          El Aaiún
# 231      Asia              Yemen    46  YEM             Sanaa
# 232    Africa             Zambia    63  ZMB            Lusaka
# 233    Africa           Zimbabwe    74  ZWE            Harare
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
group_continent=df.groupby('Continent')
rank=group_continent[['2022 Population','1970 Population']].agg(['std'])
rank
# Out:
#               2022 Population 1970 Population
#                           std             std
# Continent
# Africa           3.777349e+07    9.834611e+06
# Asia             2.822934e+08    1.411406e+08
# Europe           2.751314e+07    2.429469e+07
# North America    5.641806e+07    3.235526e+07
# Oceania          5.874435e+06    2.668785e+06
# South America    5.572581e+07    2.498639e+07

# %%
rank.plot( grid=True, ylabel='Population')
ax=plt.gca()
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x,p: format(int(x),',')))
plt.show()
